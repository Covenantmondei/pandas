# %% [markdown]
# # UDOM, JOSHUA SUNDAY
# # 22/EG/CO/1729

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Copy of Superstore.csv')

# %%
data.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
data.tail(10)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251   5/17/2015   5/23/2015  Standard Class
# 9985    9986  CA-2015-100251   5/17/2015   5/23/2015  Standard Class
# 9986    9987  CA-2016-125794   9/29/2016   10/3/2016  Standard Class
# 9987    9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9988    9989  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# ...

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace(" ", "").str.replace("-", "")

# %%
data.columns
# Out:
# Index(['RowID', 'OrderID', 'OrderDate', 'ShipDate', 'ShipMode', 'CustomerID',
#        'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
#        'Region', 'ProductID', 'Category', 'SubCategory', 'ProductName',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# STEP 8: Preview the first 10 rows of the dataset.
data.head()
# Out:
#    RowID         OrderID   OrderDate    ShipDate        ShipMode CustomerID  \
# 0      1  CA-2016-152156   11/8/2016  11/11/2016    Second Class   CG-12520
# 1      2  CA-2016-152156   11/8/2016  11/11/2016    Second Class   CG-12520
# 2      3  CA-2016-138688   6/12/2016   6/16/2016    Second Class   DV-13045
# 3      4  US-2015-108966  10/11/2015  10/18/2015  Standard Class   SO-20335
# 4      5  US-2015-108966  10/11/2015  10/18/2015  Standard Class   SO-20335
#
#       CustomerName    Segment        Country             City  ... PostalCode  \
# 0      Claire Gute   Consumer  United States        Henderson  ...      42420
# 1      Claire Gute   Consumer  United States        Henderson  ...      42420
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...      90036
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
#
# ...

# %% [markdown]
# STEP 9: Analyze dataset structure and memory usage

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   RowID         9994 non-null   int64
#  1   OrderID       9994 non-null   object
#  2   OrderDate     9994 non-null   object
#  3   ShipDate      9994 non-null   object
#  4   ShipMode      9994 non-null   object
#  5   CustomerID    9994 non-null   object
#  6   CustomerName  9994 non-null   object
#  7   Segment       9994 non-null   object
#  8   Country       9994 non-null   object
#  9   City          9994 non-null   object
#  10  State         9994 non-null   object
#  11  PostalCode    9994 non-null   int64
#  12  Region        9994 non-null   object
#  13  ProductID     9994 non-null   object
#  14  Category      9994 non-null   object
#  15  SubCategory   9994 non-null   object
#  16  ProductName   9994 non-null   object
#  17  Sales         9994 non-null   float64
# ...

# %% [markdown]
# STEP 10: Check dataset dimensions

# %%
data.shape
# Out:
# (9994, 21)

# %% [markdown]
# STEP 11: View summary statistics for Sales and Profit

# %%
data[['Sales', 'Profit']].describe()
# Out:
#               Sales       Profit
# count   9994.000000  9994.000000
# mean     229.858001    28.656896
# std      623.245101   234.260108
# min        0.444000 -6599.978000
# 25%       17.280000     1.728750
# 50%       54.490000     8.666500
# 75%      209.940000    29.364000
# max    22638.480000  8399.976000

# %% [markdown]
# STEP 12: Count of orders by Category

# %%
data['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %% [markdown]
# STEP 13: Count of orders by SubCategory

# %%
data['SubCategory'].value_counts()
# Out:
# SubCategory
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %% [markdown]
# STEP 14: Number of unique Customer IDs

# %%
data['CustomerID'].nunique()
# Out:
# 793

# %% [markdown]
# STEP 15: Number of unique Customer Names

# %%
data['CustomerName'].nunique()
# Out:
# 793

# %% [markdown]
# STEP 16: Total Sales by Region

# %%
data.groupby('Region')['Sales'].sum()
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %% [markdown]
# STEP 17: Average Profit by Category

# %%
data.groupby('Category')['Profit'].mean()
# Out:
# Category
# Furniture           8.699327
# Office Supplies    20.327050
# Technology         78.752002
# Name: Profit, dtype: float64

# %% [markdown]
# STEP 18: Average Sales by Discount level

# %%
data.groupby('Discount')['Sales'].mean()
# Out:
# Discount
# 0.00    226.742074
# 0.10    578.397351
# 0.15    529.971567
# 0.20    209.076940
# 0.30    454.742974
# 0.32    536.794770
# 0.40    565.134874
# 0.45    498.634000
# 0.50    892.705152
# 0.60     48.150000
# 0.70     97.177708
# 0.80     56.545853
# Name: Sales, dtype: float64

# %% [markdown]
# STEP 19: Average Profit by Ship Mode

# %%
data.groupby('ShipMode')['Profit'].mean()
# Out:
# ShipMode
# First Class       31.839948
# Same Day          29.266591
# Second Class      29.535545
# Standard Class    27.494770
# Name: Profit, dtype: float64

# %% [markdown]
# STEP 20: Number of orders by Segment

# %%
data.groupby('Segment')['OrderID'].count()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: OrderID, dtype: int64

# %% [markdown]
# STEP 21: Correlation between Sales, Profit, Quantity, Discount

# %%
data[['Sales', 'Profit', 'Quantity', 'Discount']].corr()
# Out:
#              Sales    Profit  Quantity  Discount
# Sales     1.000000  0.479064  0.200795 -0.028190
# Profit    0.479064  1.000000  0.066253 -0.219487
# Quantity  0.200795  0.066253  1.000000  0.008623
# Discount -0.028190 -0.219487  0.008623  1.000000

# %% [markdown]
# STEP 22: Skewness of Sales

# %%
data['Sales'].skew()
# Out:
# np.float64(12.97275234181623)

# %% [markdown]
# STEP 23: Covariance between Sales and Profit

# %%
data[['Sales', 'Profit']].cov()
# Out:
#                 Sales        Profit
# Sales   388434.455308  69944.096586
# Profit   69944.096586  54877.798055

# %% [markdown]
# STEP 24: Top 10 products by Sales

# %%
data.groupby('ProductName')['Sales'].sum().nlargest(10)
# Out:
# ProductName
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %% [markdown]
# STEP 25: Products with negative Profit

# %%
data[data['Profit'] < 0].groupby('ProductName')['OrderID'].count()
# Out:
# ProductName
# 12-1/2 Diameter Round Wall Clock                     3
# 2300 Heavy-Duty Transfer File Systems by Perma       2
# 3.6 Cubic Foot Counter Height Office Refrigerator    3
# 36X48 HARDFLOOR CHAIRMAT                             3
# 3D Systems Cube Printer, 2nd Generation, White       1
#                                                     ..
# Zipper Ring Binder Pockets                           6
# i.Sound Portable Power - 8000 mAh                    3
# iHome FM Clock Radio with Lightning Dock             1
# iOttie HLCRIO102 Car Mount                           3
# iOttie XL Car Mount                                  2
# Name: OrderID, Length: 766, dtype: int64

# %% [markdown]
# STEP 26: Total Profit by State

# %%
data.groupby('State')['Profit'].sum()
# Out:
# State
# Alabama                  5786.8253
# Arizona                 -3427.9246
# Arkansas                 4008.6871
# California              76381.3871
# Colorado                -6527.8579
# Connecticut              3511.4918
# Delaware                 9977.3748
# District of Columbia     1059.5893
# Florida                 -3399.3017
# Georgia                 16250.0433
# Idaho                     826.7231
# Illinois               -12607.8870
# Indiana                 18382.9363
# Iowa                     1183.8119
# Kansas                    836.4435
# Kentucky                11199.6966
# Louisiana                2196.1023
# Maine                     454.4862
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Michigan                24463.1876
# Minnesota               10823.1874
# Mississippi              3172.9762
# Missouri                 6436.2105
# Montana                  1833.3285
# Nebraska                 2037.0942
# ...

# %% [markdown]
# STEP 27: Top 5 customers by order count

# %%
data.groupby('CustomerID')['OrderID'].count().nlargest(5)
# Out:
# CustomerID
# WB-21850    37
# JL-15835    34
# MA-17560    34
# PP-18955    34
# CK-12205    32
# Name: OrderID, dtype: int64

# %% [markdown]
# STEP 28: Distribution of Discount levels

# %%
data['Discount'].value_counts()
# Out:
# Discount
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: count, dtype: int64

# %% [markdown]
# STEP 29: Total Quantity by Region

# %%
data.groupby('Region')['Quantity'].sum()
# Out:
# Region
# Central     8780
# East       10618
# South       6209
# West       12266
# Name: Quantity, dtype: int64

# %% [markdown]
# STEP 3: Histogram of Quantity Distribution

# %%
# Histogram of Quantities
quantities = data['Quantity']
plt.figure(figsize=(8, 5))
sns.histplot(data=quantities, bins=15, kde=False, legend=True)
plt.title('Quantity Distribution')
plt.show()

# %% [markdown]
# STEP 4: KDE of Quantity Distribution

# %%
plt.figure(figsize=(8, 5))
sns.kdeplot(data=data, x='Quantity', legend=True)
plt.title('KDE of Quantity Distribution')
plt.show()

# %% [markdown]
# Histogram of Quantity Distribution with KDE

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=quantities, bins=15, kde=True, legend=True)
plt.title('Quantity Distribution Histogram with KDE')
plt.show()

# %%
# Histogram with legend and hue
plt.figure(figsize=(10, 5))
sns.histplot(data=data,

x=data["Quantity"], bins=15, kde=False, legend=True,

hue=data["Category"])
plt.title("Quantity Distribution")
plt.show()

# %% [markdown]
# STEP 6: Quantity Distribution by Category

# %%
# Histogram plot with kde, hue and legend
plt.figure(figsize=(10, 5))
sns.histplot(data=data,

x=data["Quantity"], bins=15, kde=True, legend=True,

hue=data["Category"])
plt.title("Quantity Distribution")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.kdeplot(data=data, x='Quantity', hue='Category', legend=True)
plt.title('Quantity Distribution by Category')
plt.show()

# %% [markdown]
# STEP 7: Discount Distribution by Segment

# %%
plt.figure(figsize=(10, 5))
sns.violinplot(data=data, x='Segment', y='Discount', color="skyblue")
plt.title('Discount Distribution by Segment')
plt.show()

# %% [markdown]
# STEP 8: Boxplot of Quantity by Region

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=data, x='Region', y='Quantity', color="skyblue")
plt.title('Quantity Spread by Region')
plt.show()

# %% [markdown]
# STEP 9: Strip plot of Profit by SubCategory

# %%
plt.figure(figsize=(10, 4))
sns.stripplot(data=data, x='SubCategory', y='Profit', size=3, color="skyblue")
plt.title('Profit by SubCategory')
plt.xticks(rotation=45, ha="right")
plt.grid()
plt.show()

# %% [markdown]
# STEP 10: Swarm plot of Profit by Sub-Category

# %%
# plt.figure(figsize=(10, 4))
# sns.swarmplot(data=data, x='SubCategory', y='Profit', size=3, color="skyblue")
# plt.title('Profit by SubCategory')
# plt.xticks(rotation=45, ha="right")
# plt.grid()
# plt.show()

# %% [markdown]
# STEP 11: Bar chart of Profit by Region

# %%
sns.barplot(data=data, x='Region', y='Profit', estimator='mean',
color="skyblue")
plt.title('Average Profit by Region')
plt.show()

# %% [markdown]
# STEP 12: Bar chart of Profit by Ship Mode

# %%
plt.figure(figsize=(10,4))
sns.barplot(data=data, x='ShipMode', y='Profit', estimator='mean')
plt.title('Average Profit by Ship Mode')
plt.show()

# %% [markdown]
# STEP 13: Count plot of orders by Segment

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=data, x='Segment', color="skyblue")
plt.title('Order Count by Segment')
plt.show()

# %% [markdown]
# STEP 14: Count plot of top 10 products by order count

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=data, x='ProductID',
order=data['ProductID'].value_counts().index[:10])
plt.title('Top 10 Products by Order Count')
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# STEP 15: Count plot of Discount by Category

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=data, x='Discount', hue='Category')
plt.title('Discount Levels by Category')
plt.show()

# %% [markdown]
# STEP 16: Pie chart of Ship Mode distribution

# %%
data['ShipMode'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# STEP 17: Pie chart of Ship Mode distribution

# %%
plt.figure(figsize=(8,8))
subcat_count = data['ShipMode'].value_counts()
plt.pie(subcat_count, labels=subcat_count.index, autopct='%1.1f%%')
plt.title("Proportion of Products by Category")
plt.show()

# %% [markdown]
# STEP 18: Scatter plot of Sales vs. Profit

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(data=data, x='Sales', y='Profit')
plt.title('Sales vs. Profit')
plt.show()

# %% [markdown]
# STEP 19: Scatter plot of Quantity vs. Sales

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(data=data, x='Quantity', y='Sales')
plt.title('Quantity vs. Sales')
plt.show()

# %% [markdown]
# STEP 20: Scatter plot of Sales vs. Discount by Category

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(data=data, x='Discount', y='Sales', hue='Category')
plt.title('Sales vs. Discount by Category')
plt.show()

# %% [markdown]
# STEP 21: Scatter plot of Sales vs. Profit by Segment

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(data=data, x='Sales', y='Profit', hue='Segment')
plt.title('Sales vs. Profit by Segment')
plt.show()

# %% [markdown]
# STEP 22: Line plot of Sales by month

# %%
plt.figure(figsize=(10,4))
data['Month'] = pd.to_datetime(data['OrderDate']).dt.to_period('M')
data['Month'] = data['Month'].dt.to_timestamp()
sns.lineplot(data=data.groupby('Month')['Sales'].sum().reset_index(),
 x='Month', y='Sales', marker='o', color='steelblue')
plt.title('Monthly Sales Trends')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# STEP 23: Line plot of Profit by year

# %%
plt.figure(figsize=(10,4))
data['Year'] = pd.to_datetime(data['OrderDate']).dt.year
# data['Year'] = pd.to_datetime(data['OrderDate']).dt.year
yearly_quantity = data.groupby('Year')['Profit'].sum().reset_index()
yearly_quantity['Year'] = yearly_quantity['Year'].astype(int)
sns.lineplot(data=yearly_quantity, x ="Year", y="Profit", marker="o")
plt.title('Profit Over Time')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# STEP 24: Line plot of Profit by year

# %%
plt.figure(figsize=(10, 4))
data['Year'] = pd.to_datetime(data['OrderDate']).dt.year
yearly_quantity = data.groupby('Year')['Profit'].sum().reset_index()
yearly_quantity['Year'] = yearly_quantity['Year'].astype(int)
sns.lineplot(data=yearly_quantity, x="Year", y="Profit", marker="o")
plt.title('Profit Over Time')
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(ticks=yearly_quantity['Year']) #This line ensures no decimal points
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 25: Line plot of Profit by Category over time

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=data, x='Month', y='Profit', hue='Category')
plt.title('Profit by Category Over Time')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# STEP 26: Average Discount by Month

# %%
data['Month'] = pd.to_datetime(data['OrderDate']).dt.to_period('M')
data['Month'] = data['Month'].dt.to_timestamp()
# Group by Month and calculate average Discount
monthly_discount = data.groupby('Month')['Discount'].mean().reset_index()
# Plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=monthly_discount, x='Month', y='Discount', marker='o',
color='darkorange')
plt.title('Average Discount by Month')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 27: Line plot of Profit by Segment over time

# %%
# Ensure Month is in timestamp format
data['Month'] = pd.to_datetime(data['OrderDate']).dt.to_period('M').dt.to_timestamp()
# Group by Month and Segment, then calculate total Profit
monthly_profit = data.groupby(['Month',
'Segment'])['Profit'].sum().reset_index()
# Plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=monthly_profit, x='Month', y='Profit', hue='Segment',
marker='o')
plt.title('Profit by Segment Over Time')
plt.xlabel('Month')
plt.ylabel('Total Profit')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 28: Area plot of order count by ShipMode

# %%
# Prepare the data: count orders by Month and ShipMode
area_data = data.groupby(['Month',
'ShipMode'])['OrderID'].count().unstack().fillna(0)
# Plot as area chart
area_data.plot.area(figsize=(10, 6), alpha=0.7)
plt.title('Monthly Order Count by Ship Mode')
plt.xlabel('Month')
plt.ylabel('Order Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 29: Correlation Heatmap of Sales, Profit, Quantity, and Discount (cannot=True).

# %%
# Correlation heatmap
corr_matrix = data[['Sales', 'Profit', 'Quantity', 'Discount']].corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 30: Correlation Heatmap of Sales, Profit, Quantity, and Discount (annot=False).

# %%
# Correlation heatmap
corr_matrix = data[['Sales', 'Profit', 'Quantity', 'Discount']].corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=False, cmap='Blues', cbar=False)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 31: Correlation Heatmap of Sales, Profit, Quantity, and Discount (Lower Triangle).

# %%
mask = np.triu(np.ones_like(corr_matrix), k=1)
plt.figure(figsize=(10, 6))
sns.heatmap(
 corr_matrix,
 annot=True,
 cmap='coolwarm',
 vmin=-1,
 vmax=1,
 center=0,
 mask=mask,
 cbar=False,
)
plt.title("Correlation Matrix (Lower Triangle)\n")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# STEP 32: Heatmap of Profit by Region and Category

# %%
profit_pivot = data.pivot_table(values='Profit',
 index='Region',
 columns='Category',
 aggfunc='mean')
plt.figure(figsize=(10, 6))
sns.heatmap(profit_pivot, annot=True, cmap='RdYlGn')
plt.title('Profit by Region and Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 33: Heatmap of missing data

# %%
missing_data = data.isnull()
plt.figure(figsize=(10, 10))
sns.heatmap(missing_data, cbar=False, cmap='Blues')
plt.title('Missing Data Heatmap')
plt.grid(True)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 34: Pair plot of Sales, Profit, Quantity, Discount

# %%
# Pair plot of Sales, Profit, Quantity, Discount
pair_data = data[['Sales', 'Profit', 'Quantity', 'Discount', 'Segment']]
g = sns.pairplot(data=pair_data,
 # hue='Segment',
 diag_kind='hist',
 palette='Set2',
 height=2.5)
# Add grid to each inner plot
for ax in g.axes.flatten():
    if ax is not None:
        ax.grid(True, linestyle='--', alpha=0.4)
# Add title and spacing
plt.suptitle('Pairwise Relationships by Segment', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\Governor\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\Governor\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\Governor\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\Governor\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# ...

# %% [markdown]
# STEP 35: Pair plot of Sales, Profit, Quantity, Discount (with Hue)

# %%
pair_data = data[['Sales', 'Profit', 'Quantity', 'Discount', 'Segment']]
g = sns.pairplot(data=pair_data,
 hue='Segment',
 diag_kind='kde',
 palette='tab10', # Try 'husl', 'pastel', 'tab10', etc.
 height=2)
# Add grid to each inner plot
for ax in g.axes.flatten():
    if ax is not None:
        ax.grid(True, linestyle='--', alpha=0.1)
# Add title and spacing
plt.suptitle('Pairwise Relationships by Segment', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 36: Pairwise Relationships and Distributions of Sales, Profit, Quantity, and Discount, with Linear
# Regression Fits.

# %%
# Pair plot of Sales, Profit, Quantity, Discount
pair_data = data[['Sales', 'Profit', 'Quantity', 'Discount', 'Segment']]
g = sns.pairplot(data=pair_data,
 # hue='Segment',
 diag_kind='auto',
 kind="reg",
 palette='tab10', # Try 'husl', 'pastel', 'tab10', etc.
 height=2.5,)
# Add grid to each inner plot
for ax in g.axes.flatten():
    if ax is not None:
        ax.grid(True, linestyle='--', alpha=0.1)
# Add title and spacing
plt.suptitle('Pairwise Relationships by Segment', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\Governor\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\Governor\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\Governor\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\Governor\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)

# %% [markdown]
# STEP 37: Facet grid of Sales by Category and Region

# %%
facet_sales_region = data[['Category', 'Sales', 'Region']]
g = sns.catplot(data=facet_sales_region,
 x='Category',
 y='Sales',
 col='Region',
 kind='bar',
 col_wrap=2,
 height=3,
 aspect=1.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 38: Facet grid of Sales by Category and Region (with palette = “Set2”)

# %%
facet_sales_region = data[['Category', 'Sales', 'Region']].copy()
g = sns.catplot(data=facet_sales_region,
 x='Category',
 y='Sales',
 col='Region',
 kind='bar',
 col_wrap=2, # 2x2 layout
 height=4,
 aspect=1.2,
 palette='Set2')
# Give plots breathing room
g.fig.subplots_adjust(top=0.9, bottom=0.25)
plt.show()
# Out:
# C:\Users\Governor\AppData\Local\Temp\ipykernel_10440\1975822875.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(data=facet_sales_region,

# %% [markdown]
# STEP 39: Facet grid of Profit by Segment and ShipMode

# %%
facet_profit_ship = data[['Segment', 'Profit', 'ShipMode']]
sns.catplot(data=facet_profit_ship,
 x='Segment',
 y='Profit',
 col='ShipMode',
 kind='box',
 col_wrap=2,
 )
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 40: Facet grid of Quantity by State and Segment

# %%
facet_quantity_state = data[['Segment', 'Quantity', 'State']]
sns.catplot(data=facet_quantity_state,
 x='Segment',
 y='Quantity',
 col='State',
 kind='box',
 col_wrap=4,
 height=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 41: Joint plot of Sales and Profit

# %%
joint_data = data[['Sales', 'Discount', 'Category']]
sns.jointplot(data=joint_data, x='Sales', y='Discount', hue='Category',
height=8 )
plt.suptitle('Sales vs. Profit by Category', y=1.02)
plt.show()
