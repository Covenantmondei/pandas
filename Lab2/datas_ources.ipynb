# %%
import pandas as pd

# %%
csv_data = pd.read_csv("datasets/Social_Network_Ads_CSV.csv")
csv_data.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
delimeter_data = pd.read_csv("datasets/Social_Network_Ads_CSV.csv")
delimeter_data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
csv_data = pd.read_csv("datasets/Social_Network_Ads_CSV.csv", header=None)
csv_data.head(10)
# Out:
#           0       1    2                3          4
# 0   User ID  Gender  Age  EstimatedSalary  Purchased
# 1  15624510    Male   19            19000          0
# 2  15810944    Male   35            20000          0
# 3  15668575  Female   26            43000          0
# 4  15603246  Female   27            57000          0
# 5  15804002    Male   19            76000          0
# 6  15728773    Male   27            58000          0
# 7  15598044  Female   27            84000          0
# 8  15694829  Female   32           150000          1
# 9  15600575    Male   25            33000          0

# %%
new_header = pd.read_csv("datasets/Social_Network_Ads_CSV.csv", names=['SID', 'SGender', 'SAge', 'SSalary', 'SPurchased'])
new_header.head(10)
# Out:
#         SID SGender SAge          SSalary SPurchased
# 0   User ID  Gender  Age  EstimatedSalary  Purchased
# 1  15624510    Male   19            19000          0
# 2  15810944    Male   35            20000          0
# 3  15668575  Female   26            43000          0
# 4  15603246  Female   27            57000          0
# 5  15804002    Male   19            76000          0
# 6  15728773    Male   27            58000          0
# 7  15598044  Female   27            84000          0
# 8  15694829  Female   32           150000          1
# 9  15600575    Male   25            33000          0

# %%
excel_df = pd.read_excel("datasets/New_Social_Network_Ads_Data.xlsx")
excel_df.head()
# Out:
#      UserID  Gender  Age  EstimatedSalary  Purchased
# 0  15566689  Female   35            57000      False
# 1  15569641  Female   58            95000       True
# 2  15570769  Female   26            80000      False
# 3  15570932    Male   34           115000      False
# 4  15571059  Female   33            41000      False

# %%
url = "https://github.com/sakshi2k/Social_Network_Ads/blob/master/Social_Network_Ads.csv"
url_df = pd.read_csv(url)
url_df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 url = "https://github.com/sakshi2k/Social_Network_Ads/blob/master/Social_Network_Ads.csv"
# ----> 2 url_df = pd.read_csv(url)
#       3 url_df.head()
#
# ...

# %%
json_df = pd.read_json("datasets/Social_Network_Ads_JSON.json")
json_df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
html_df = pd.read_html("datasets/Social_Network_Ads_HTML.html" [0])
html_df.head()
# Out:
# C:\Users\Governor\AppData\Local\Temp\ipykernel_5056\630926639.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   html_df = pd.read_html("datasets/Social_Network_Ads_HTML.html" [0])
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Governor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\Governor\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# ...
