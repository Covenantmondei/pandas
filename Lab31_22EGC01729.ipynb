# %% [markdown]
# Name: Udom, Joshua Sunday
#
# Registration Number: 22/EG/CO/1729

# %% [markdown]
# 0. Importing from my Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
#    1.Import project dependencies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Read the Superstore dataset from a CSV file into a pandas dataframe

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Copy of Superstore.csv')

# %% [markdown]
# 3. Preview first 10 rows of the dataset

# %%
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %% [markdown]
# 4. Preview last 10 rows of the dataset

# %%
df.tail(10)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251   5/17/2015   5/23/2015  Standard Class
# 9985    9986  CA-2015-100251   5/17/2015   5/23/2015  Standard Class
# 9986    9987  CA-2016-125794   9/29/2016   10/3/2016  Standard Class
# 9987    9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9988    9989  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# ...

# %% [markdown]
# 5. Preview 10 random rows

# %%
df.sample(10)
# Out:
#       RowID         OrderID  OrderDate   ShipDate        ShipMode CustomerID  \
# 6292   6293  CA-2015-151253  4/22/2015  4/26/2015  Standard Class   AZ-10750
# 665     666  CA-2017-132682   6/8/2017  6/10/2017    Second Class   TH-21235
# 240     241  CA-2016-157749   6/4/2016   6/9/2016    Second Class   KL-16645
# 6103   6104  CA-2017-100111  9/20/2017  9/26/2017  Standard Class   SV-20365
# 9426   9427  CA-2016-160479  9/15/2016  9/20/2016  Standard Class   AH-10585
# 8629   8630  CA-2015-164084   9/7/2015  9/12/2015  Standard Class   AG-10525
# 2720   2721  CA-2014-121286  11/4/2014  11/8/2014    Second Class   ON-18715
# 917     918  US-2014-141215  6/15/2014  6/21/2014  Standard Class   KL-16555
# 9081   9082  CA-2017-166898  9/11/2017  9/13/2017    Second Class   KH-16630
# 9207   9208  CA-2017-140781   8/3/2017   8/7/2017  Standard Class   AB-10105
#
#        CustomerName    Segment        Country           City  ... PostalCode  \
# ...

# %% [markdown]
# 6. View all column headers in the DataFrame

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# 7. Standardize column names (remove all spaces and dashes)

# %%
df.columns = df.columns.str.replace(" ", "").str.replace("-", "")

# %% [markdown]
# 8. Preview the first 10 rows of the dataset.

# %%
df.head(10)
# Out:
#    RowID         OrderID   OrderDate    ShipDate        ShipMode CustomerID  \
# 0      1  CA-2016-152156   11/8/2016  11/11/2016    Second Class   CG-12520
# 1      2  CA-2016-152156   11/8/2016  11/11/2016    Second Class   CG-12520
# 2      3  CA-2016-138688   6/12/2016   6/16/2016    Second Class   DV-13045
# 3      4  US-2015-108966  10/11/2015  10/18/2015  Standard Class   SO-20335
# 4      5  US-2015-108966  10/11/2015  10/18/2015  Standard Class   SO-20335
# 5      6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class   BH-11710
# 6      7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class   BH-11710
# 7      8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class   BH-11710
# 8      9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class   BH-11710
# 9     10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class   BH-11710
#
#       CustomerName    Segment        Country             City  ... PostalCode  \
# ...

# %% [markdown]
# 9. Analyze dataset structure and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   RowID         9994 non-null   int64
#  1   OrderID       9994 non-null   object
#  2   OrderDate     9994 non-null   object
#  3   ShipDate      9994 non-null   object
#  4   ShipMode      9994 non-null   object
#  5   CustomerID    9994 non-null   object
#  6   CustomerName  9994 non-null   object
#  7   Segment       9994 non-null   object
#  8   Country       9994 non-null   object
#  9   City          9994 non-null   object
#  10  State         9994 non-null   object
#  11  PostalCode    9994 non-null   int64
#  12  Region        9994 non-null   object
#  13  ProductID     9994 non-null   object
#  14  Category      9994 non-null   object
#  15  SubCategory   9994 non-null   object
#  16  ProductName   9994 non-null   object
#  17  Sales         9994 non-null   float64
# ...

# %% [markdown]
# 10. Check dataset dimensions.

# %%
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# 11. View summary statistics for Sales and Profit

# %%
df[['Sales', 'Profit']].describe()
# Out:
#               Sales       Profit
# count   9994.000000  9994.000000
# mean     229.858001    28.656896
# std      623.245101   234.260108
# min        0.444000 -6599.978000
# 25%       17.280000     1.728750
# 50%       54.490000     8.666500
# 75%      209.940000    29.364000
# max    22638.480000  8399.976000

# %% [markdown]
# 12. Count of orders by Category

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %% [markdown]
# 13. Count of orders by SubCategory

# %%
df['SubCategory'].value_counts()
# Out:
# SubCategory
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %% [markdown]
# 14.Number of unique Customer IDs

# %%
df['CustomerID'].nunique()
# Out:
# 793

# %% [markdown]
# 15. Number of unique Customer Names

# %%
df['CustomerName'].nunique()
# Out:
# 793

# %% [markdown]
# 16. Total Sales by Region

# %%
df.groupby('Region')['Sales'].sum()
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %% [markdown]
# 17. Average Profit by Category

# %%
df.groupby('Category')['Profit'].mean()
# Out:
# Category
# Furniture           8.699327
# Office Supplies    20.327050
# Technology         78.752002
# Name: Profit, dtype: float64

# %% [markdown]
# 18. Average Sales by Discount level

# %%
df.groupby('Discount')['Sales'].mean()
# Out:
# Discount
# 0.00    226.742074
# 0.10    578.397351
# 0.15    529.971567
# 0.20    209.076940
# 0.30    454.742974
# 0.32    536.794770
# 0.40    565.134874
# 0.45    498.634000
# 0.50    892.705152
# 0.60     48.150000
# 0.70     97.177708
# 0.80     56.545853
# Name: Sales, dtype: float64

# %% [markdown]
# 19. Average Profit by Ship Mode

# %%
df.groupby('ShipMode')['Profit'].mean()
# Out:
# ShipMode
# First Class       31.839948
# Same Day          29.266591
# Second Class      29.535545
# Standard Class    27.494770
# Name: Profit, dtype: float64

# %% [markdown]
# 20. Number of orders by Segment

# %%
df.groupby('Segment')['OrderID'].count()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: OrderID, dtype: int64

# %% [markdown]
# 21. Correlation between Sales, Profit, Quantity, Discount

# %%
df[['Sales', 'Profit', 'Quantity', 'Discount']].corr()
# Out:
#              Sales    Profit  Quantity  Discount
# Sales     1.000000  0.479064  0.200795 -0.028190
# Profit    0.479064  1.000000  0.066253 -0.219487
# Quantity  0.200795  0.066253  1.000000  0.008623
# Discount -0.028190 -0.219487  0.008623  1.000000

# %% [markdown]
# 22. Skewness of Sales

# %%
df['Sales'].skew()
# Out:
# np.float64(12.97275234181623)

# %% [markdown]
# 23. Covariance between Sales and Profit

# %%
df[['Sales', 'Profit']].cov()
# Out:
#                 Sales        Profit
# Sales   388434.455308  69944.096586
# Profit   69944.096586  54877.798055

# %% [markdown]
# 24. Top 10 products by Sales

# %%
df.groupby('ProductName')['Sales'].sum().nlargest(10)
# Out:
# ProductName
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %% [markdown]
# 25. Products with negative Profit

# %%
df[df['Profit'] < 0].groupby('ProductName')['OrderID'].count()
# Out:
# ProductName
# 12-1/2 Diameter Round Wall Clock                     3
# 2300 Heavy-Duty Transfer File Systems by Perma       2
# 3.6 Cubic Foot Counter Height Office Refrigerator    3
# 36X48 HARDFLOOR CHAIRMAT                             3
# 3D Systems Cube Printer, 2nd Generation, White       1
#                                                     ..
# Zipper Ring Binder Pockets                           6
# i.Sound Portable Power - 8000 mAh                    3
# iHome FM Clock Radio with Lightning Dock             1
# iOttie HLCRIO102 Car Mount                           3
# iOttie XL Car Mount                                  2
# Name: OrderID, Length: 766, dtype: int64

# %% [markdown]
# 26. Total Profit by State

# %%
df.groupby('State')['Profit'].sum()
# Out:
# State
# Alabama                  5786.8253
# Arizona                 -3427.9246
# Arkansas                 4008.6871
# California              76381.3871
# Colorado                -6527.8579
# Connecticut              3511.4918
# Delaware                 9977.3748
# District of Columbia     1059.5893
# Florida                 -3399.3017
# Georgia                 16250.0433
# Idaho                     826.7231
# Illinois               -12607.8870
# Indiana                 18382.9363
# Iowa                     1183.8119
# Kansas                    836.4435
# Kentucky                11199.6966
# Louisiana                2196.1023
# Maine                     454.4862
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Michigan                24463.1876
# Minnesota               10823.1874
# Mississippi              3172.9762
# Missouri                 6436.2105
# Montana                  1833.3285
# Nebraska                 2037.0942
# ...

# %% [markdown]
# 27.  Top 5 customers by order count

# %%
df.groupby('CustomerID')['OrderID'].count().nlargest(5)
# Out:
# CustomerID
# WB-21850    37
# JL-15835    34
# MA-17560    34
# PP-18955    34
# CK-12205    32
# Name: OrderID, dtype: int64

# %% [markdown]
# 28. Distribution of Discount levels

# %%
df['Discount'].value_counts()
# Out:
# Discount
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: count, dtype: int64

# %% [markdown]
# 29. Total Quantity by Region

# %%
df.groupby('Region')['Quantity'].sum()
# Out:
# Region
# Central     8780
# East       10618
# South       6209
# West       12266
# Name: Quantity, dtype: int64
